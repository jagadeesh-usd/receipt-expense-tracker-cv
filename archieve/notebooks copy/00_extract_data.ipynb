# %%
import kagglehub

# %%
print("Downloading SROIE dataset from Kaggle...")

path = kagglehub.dataset_download("urbikn/sroie-datasetv2")
print("Dataset downloaded to:", path)
# Out:
# ...
# 100%|██████████| 834M/834M [00:53<00:00, 16.4MB/s]
# Extracting files...
# Dataset downloaded to: /Users/jagadeesch/.cache/kagglehub/datasets/urbikn/sroie-datasetv2/versions/4

# %%
# !cp -R /Users/jagadeesch/.cache/kagglehub/datasets/urbikn/sroie-datasetv2/versions/4/SROIE2019 \
    /Users/jagadeesch/ai_projects/receipt-expense-tracker-cv/data/raw/

# %%
# !ls -R ../data/raw/SROIE2019
# Out:
# layoutlm-base-uncased test                  train
#
# ../data/raw/SROIE2019/layoutlm-base-uncased:
# config.json             special_tokens_map.json training_args.bin
# pytorch_model.bin       tokenizer_config.json   vocab.txt
#
# ../data/raw/SROIE2019/test:
# box      entities img
#
# ../data/raw/SROIE2019/test/box:
# X00016469670.txt  X51005715455.txt  X51006392167.txt  X51006856982.txt
# X00016469671.txt  X51005719823.txt  X51006401845.txt  X51006857126.txt
# X51005200931.txt  X51005719855.txt  X51006401853.txt  X51006857132.txt
# X51005230605.txt  X51005719857.txt  X51006401977.txt  X51006857137.txt
# X51005230616.txt  X51005719863.txt  X51006414425.txt  X51006857540.txt
# X51005230621.txt  X51005719888.txt  X51006414427.txt  X51006912959.txt
# X51005230648.txt  X51005719889.txt  X51006414433.txt  X51006912976.txt
# X51005230657.txt  X51005719895.txt  X51006414512.txt  X51006912998.txt
# X51005230659.txt  X51005719898.txt  X51006414532.txt  X51006913018.txt
# ...
