# %%
# !pip install easyocr
# Out:
# Requirement already satisfied: easyocr in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (1.7.2)
# Requirement already satisfied: torch in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (2.9.1)
# Requirement already satisfied: torchvision>=0.5 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (0.24.1)
# Requirement already satisfied: opencv-python-headless in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (4.12.0.88)
# Requirement already satisfied: scipy in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (1.13.1)
# Requirement already satisfied: numpy in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (2.2.6)
# Requirement already satisfied: Pillow in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (11.1.0)
# Requirement already satisfied: scikit-image in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (0.6.7)
# Requirement already satisfied: PyYAML in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: pyclipper in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: filelock in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from torch->easyocr) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from torch->easyocr) (4.15.0)
# Requirement already satisfied: setuptools in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from torch->easyocr) (75.8.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from torch->easyocr) (3.5)
# Requirement already satisfied: jinja2 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from torch->easyocr) (2024.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from jinja2->torch->easyocr) (3.0.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from scikit-image->easyocr) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from scikit-image->easyocr) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from scikit-image->easyocr) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/jagadeesch/USD/venv/lib/python3.12/site-packages (from scikit-image->easyocr) (0.4)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import json
from pathlib import Path
import numpy as np
import easyocr

# %%
# init reader 
reader = easyocr.Reader(['en'], gpu=True)

def serialize_easyocr_result(result):
    """
    Convert a single easyocr result tuple (bbox, text, conf)
    into JSON-serializable dict.
    result: (bbox, text, conf) where bbox may be np.array or nested lists.
    """
    bbox, text, conf = result
    # bbox might be np.ndarray or list of np.int32 => convert every coord to int
    try:
        bbox_list = [[int(x) for x in point] for point in bbox]
    except Exception:
        # safer fallback
        bbox_list = []
        for point in bbox:
            bbox_list.append([int(point[0]), int(point[1])])

    # conf may be numpy.float32 => convert to float
    conf_f = float(conf)

    return {"bbox": bbox_list, "text": str(text), "conf": conf_f}

def extract_text_serializable(image_path: str):
    """
    Runs easyocr and returns a JSON-serializable dict with:
      - lines: list of texts
      - full_text: string with newlines
      - raw: list of serialized result dicts [{bbox, text, conf}, ...]
    """
    raw = reader.readtext(image_path, detail=1)
    lines = [r[1] for r in raw]
    full_text = "\n".join(lines)
    serial = [serialize_easyocr_result(r) for r in raw]
    return {"lines": lines, "full_text": full_text, "raw": serial}

# %%
# Batch run  
PROCESSED_DIR = Path("../data/processed/SROIE2019")
OCR_OUTPUT_DIR = Path("../data/processed/ocr")
OCR_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

splits = ["train", "test"]

for split in splits:
    img_dir = PROCESSED_DIR / split
    out_dir = OCR_OUTPUT_DIR / split
    out_dir.mkdir(parents=True, exist_ok=True)

    print(f"Running OCR on {split} set...")

    for img_path in sorted(img_dir.glob("*")):
        out_file = out_dir / f"{img_path.stem}.json"

        result = extract_text_serializable(str(img_path))

        # write JSON safely
        with open(out_file, "w", encoding="utf-8") as f:
            json.dump(result, f, indent=2, ensure_ascii=False)

print("✔ OCR extraction complete!")
